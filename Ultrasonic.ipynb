# %%
#!/usr/bin/env python
import RPi.GPIO as GPIO
import time
TRIG = 11
ECHO = 12
MIN_T = 0.00011764705
MAX_T = 0.02352941176

def sonic_setup():
    GPIO.setmode(GPIO.BOARD)
    GPIO.setup(TRIG, GPIO.OUT)
    GPIO.setup(ECHO, GPIO.IN)

def duration():
    GPIO.output(TRIG, 0)
    time.sleep(0.000002)
    GPIO.output(TRIG, 1)
    time.sleep(0.00001)
    GPIO.output(TRIG, 0)
    while GPIO.input(ECHO) == 0: pass
    time1 = time.time()
    while GPIO.input(ECHO) == 1: pass
    time2 = time.time()
    t = time2 - time1
    if (MIN_T < t < MAX_T): return t 
    else: return False

if __name__ == "__main__":
    sonic_setup()
    try:
        while True:
            print(distance(), 'cm')
            print('')
            time.sleep(0.3)
    except KeyboardInterrupt: print('User interrupted')
    finally: GPIO.cleanup()
# Out:
# Bogus!
# 2230.5309772491455 cm
#
# Bogus!
# 2341.5215015411377 cm
#
# 128.35407257080078 cm
#
# 17.785072326660156 cm
#
# 17.22574234008789 cm
#
# 17.809391021728516 cm
#
# 17.424345016479492 cm
#
# 17.939090728759766 cm
#
# 19.900798797607422 cm
#
# 90.51012992858887 cm
#
# 112.19024658203125 cm
#
# 94.2227840423584 cm
#
# 135.52403450012207 cm
#
# 107.8493595123291 cm
#
# 124.59683418273926 cm
#
# 112.95628547668457 cm
#
# Bogus!
# 591.163158416748 cm
#
# 92.1030044555664 cm
#
# 146.21210098266602 cm
#
# 94.07687187194824 cm
#
# 151.17716789245605 cm
#
# 95.43466567993164 cm
#
# 75.91080665588379 cm
#
# 61.69247627258301 cm
#
# 79.55455780029297 cm
#
# 61.59520149230957 cm
#
# User interrupted
