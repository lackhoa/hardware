# %%
#!/usr/bin/env python
import RPi.GPIO as GPIO
import time
TRIG = 11
ECHO = 12
MIN_T = 0.00011764705
MAX_T = 0.02352941176

def sonic_setup():
    GPIO.setmode(GPIO.BOARD)
    GPIO.setup(TRIG, GPIO.OUT)
    GPIO.setup(ECHO, GPIO.IN)

def duration():
    GPIO.output(TRIG, 0)
    time.sleep(0.000002)
    GPIO.output(TRIG, 1)
    time.sleep(0.00001)
    GPIO.output(TRIG, 0)
    while GPIO.input(ECHO) == 0: pass
    time1 = time.time()
    while GPIO.input(ECHO) == 1: pass
    time2 = time.time()
    t = time2 - time1
    if (MIN_T < t < MAX_T): return t 
    else: return False

if __name__ == "__main__":
    sonic_setup()
    try:
        while True:
            print(duration(), 's')
            print('')
            time.sleep(0.3)
    except KeyboardInterrupt: print('User interrupted')
    finally: GPIO.cleanup()
# Out:
# False cm
#
# False cm
#
# False cm
#
# False cm
#
# False cm
#
# False cm
#
# 0.00019860267639160156 cm
#
# 0.00048828125 cm
#
# False cm
#
# 0.0014214515686035156 cm
#
# False cm
#
# 0.008462905883789062 cm
#
# False cm
#
# 0.014209985733032227 cm
#
# 0.014078855514526367 cm
#
# 0.01405644416809082 cm
#
# 0.014080286026000977 cm
#
# 0.014073371887207031 cm
#
# False cm
#
# False cm
#
# False cm
#
# False cm
#
# 0.0057220458984375 cm
#
# False cm
#
# False cm
#
# False cm
#
# 0.004070281982421875 cm
#
# False cm
#
# 0.0057811737060546875 cm
#
# False cm
#
# False cm
#
# False cm
#
# 0.0006890296936035156 cm
#
# False cm
#
# 0.003680706024169922 cm
#
# False cm
#
# 0.0049517154693603516 cm
#
# False cm
#
# 0.001093149185180664 cm
#
# 0.0009949207305908203 cm
#
# False cm
#
# 0.0009870529174804688 cm
#
# 0.0010437965393066406 cm
#
# 0.0005223751068115234 cm
#
# 0.0009622573852539062 cm
#
# False cm
#
# 0.0006542205810546875 cm
#
# 0.0008263587951660156 cm
#
# False cm
#
# 0.0003211498260498047 cm
#
# False cm
#
# 0.00024771690368652344 cm
#
# False cm
#
# 0.0003757476806640625 cm
#
# 0.0004222393035888672 cm
#
# 0.0004227161407470703 cm
#
# False cm
#
# User interrupted
